# %% [markdown]
# # Medical Insurance Cost Prediction (Regression)
#
# **CAIR Collective Curriculum Project**
#
# In this project, you'll build and compare machine learning models that predict **medical insurance charges** from patient demographics and health indicators.
#
# ## What you’ll practice
# - Loading and exploring tabular data (EDA)
# - Cleaning + preprocessing (categoricals, scaling)
# - Training regression models
# - Evaluating models (MAE, RMSE, R²)
# - Comparing models + selecting a final model
# - (Optional) Feature importance / interpretability
#
# > **Dataset:** `insurance.csv` (Kaggle “Medical Cost Personal Datasets”)
# > Place it at: `data/raw/insurance.csv` **or** update the `DATA_PATH` below.

# %%
# =========================================
# 1) Setup
# =========================================
# TODO: Run this cell first.

import os
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Models (we will compare a few)
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor

RANDOM_STATE = 42
DATA_PATH = "data/raw/insurance.csv"  # TODO: update if needed

def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# %% [markdown]
# ## 2) Load the data
#
# We’ll load `insurance.csv` into a pandas DataFrame and do quick sanity checks:
# - shape (rows, columns)
# - column names + types
# - missing values

# %%
# TODO: Load the CSV from DATA_PATH
# Hints:
# - use pd.read_csv(...)
# - print df.head()
# - check df.info()
# - check df.isna().sum()

df = None  # TODO

# TODO: Replace the lines below after you load df
# display(df.head())
# df.info()
# df.isna().sum()

# %% [markdown]
# ## 3) Exploratory Data Analysis (EDA)
#
# Goal: understand distributions and relationships.
#
# Suggested EDA:
# - Summary stats for numeric columns
# - Histograms for `age`, `bmi`, `charges`
# - Bar counts for `sex`, `smoker`, `region`
# - Compare charges by smoker vs non-smoker
# - Correlation of numeric features with `charges`

# %%
# TODO: Basic summary stats
# display(df.describe())

# TODO: Histograms (example below)
# df["charges"].hist(bins=30)
# plt.title("Distribution of Charges")
# plt.show()

# TODO: Compare charges by smoker
# df.boxplot(column="charges", by="smoker")
# plt.title("Charges by Smoker")
# plt.suptitle("")
# plt.show()

# TODO: Any 1 insight you notice (write in a markdown cell below)

# %% [markdown]
# ### EDA observation
#
# TODO: Write **1–3 sentences** about what you noticed (e.g., smoker vs non-smoker differences).

# %% [markdown]
# ## 4) Train/Test Split + Preprocessing
#
# We’ll predict:
# - **Target:** `charges`
# - **Features:** everything else
#
# Preprocessing:
# - **Numeric:** standardize (mean 0, std 1)
# - **Categorical:** one-hot encode (`sex`, `smoker`, `region`)

# %%
# TODO: Separate features (X) and target (y)
X = None  # TODO: df.drop(columns=["charges"])
y = None  # TODO: df["charges"]

# TODO: Identify numeric and categorical columns
numeric_features = None       # TODO
categorical_features = None   # TODO

# TODO: Build preprocessing transformer
preprocess = None  # TODO: ColumnTransformer(...)

# TODO: Train/test split
X_train, X_test, y_train, y_test = None, None, None, None  # TODO

# %% [markdown]
# ## 5) Baseline Model + Metrics
#
# We'll use these metrics:
# - **MAE** (average absolute error)
# - **RMSE** (penalizes large errors)
# - **R²** (variance explained; higher is better)

# %%
# TODO: Create a baseline model pipeline using LinearRegression
# Hint:
# model = Pipeline(steps=[("preprocess", preprocess), ("model", LinearRegression())])
# model.fit(X_train, y_train)
# preds = model.predict(X_test)
# print metrics

baseline_model = None  # TODO

# %% [markdown]
# ## 6) Compare Multiple Models (quick benchmark)
#
# We'll compare a few models with minimal tuning:
# - Linear Regression
# - Ridge
# - Lasso
# - Random Forest
# - Gradient Boosting
#
# We’ll evaluate on the **same** train/test split for fairness.

# %%
# TODO: Fill in the models dictionary and loop through to evaluate each one.
# Tips:
# - Put each estimator inside a Pipeline with the same 'preprocess'
# - Store results in a DataFrame for easy comparison

models = {
    # "LinearRegression": LinearRegression(),
    # "Ridge": Ridge(alpha=1.0, random_state=RANDOM_STATE)  # note: Ridge doesn't take random_state in sklearn
    # ...
}

results = []

# TODO: loop, fit, predict, compute MAE/RMSE/R2, append to results
# results_df = pd.DataFrame(results).sort_values("RMSE")
# display(results_df)

# %% [markdown]
# ## 7) Hyperparameter Tuning (example)
#
# Pick **one** strong model (often Gradient Boosting or Random Forest) and run a small `GridSearchCV`.
#
# > Keep grids small for classroom time.

# %%
# TODO: Choose a model to tune (suggestion: GradientBoostingRegressor)
# 1) Create a pipeline: preprocess + model
# 2) Define a param_grid (small!)
# 3) Run GridSearchCV
# 4) Evaluate best estimator on the test set

best_model = None  # TODO

# %% [markdown]
# ## 8) Interpretability (optional)
#
# Two approachable options:
# 1. **Permutation importance** (model-agnostic, built into sklearn)
# 2. **SHAP** (more advanced; extra dependency)
#
# We’ll show permutation importance as the default.

# %%
# TODO (optional): Permutation importance
# from sklearn.inspection import permutation_importance
# r = permutation_importance(best_model, X_test, y_test, n_repeats=10, random_state=RANDOM_STATE)
# ... (plot top features)

# %% [markdown]
# ## 9) Final Write-up (student deliverable)
#
# In **3–6 bullet points**, answer:
# - Which model performed best? (use RMSE + R²)
# - What features seem most important?
# - Any surprising patterns from EDA?
# - One limitation of this dataset/model
# - One improvement you would try next
